# %%
# %gui qt5

# %%
from PyQt5.QtWidgets import QApplication
import sys
import os

app = QApplication.instance()
if app is None:
    app = QApplication(sys.argv)

# %%
from visualens.fits_image import fits_image
# Out:
# /opt/anaconda3/envs/visualens_test_env/lib/python3.11/site-packages/arviz/__init__.py:50: FutureWarning:
# ArviZ is undergoing a major refactor to improve flexibility and extensibility while maintaining a user-friendly interface.
# Some upcoming changes may be backward incompatible.
# For details and migration guidance, visit: https://python.arviz.org/en/latest/user_guide/migration_guide.html
#   warn(

# %%
sys.path.append( os.path.join(os.path.expanduser("~"), 'Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/') )
from Lenstool_GUI.visualens.fits_image import fits_image

# %%
DATA_dir = os.path.join( os.path.dirname(os.getcwd()), 'DATA' )

# %%
im = fits_image(DATA_dir + "/RGB_cropped.fits")
im.boost()
# Out:
# 3 image hdus found.
# HDU 0 contains image data with shape (5398, 5210)
# HDU 1 contains image data with shape (5398, 5210)
# HDU 2 contains image data with shape (5398, 5210)
# 3 non empty images found.
# keyword is None
# No 'SCI' extname found.
# Assuming RGB data.
# Boosted image found: /Users/tom/Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/Lenstool_GUI/examples/DATA/RGB_cropped_boosted.fits
# 3 image hdus found.
# HDU 0 contains image data with shape (5398, 5210)
# HDU 1 contains image data with shape (5398, 5210)
# HDU 2 contains image data with shape (5398, 5210)
# 3 non empty images found.
# keyword is EXTNAME
# Assuming RGB data.
# Creating main window...
# Done
# Plotting...
# Done

# %%
im.load_filters()
# Out:
# Looking for filters in directory: /Users/tom/Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/Lenstool_GUI/examples/DATA/FILTERS
# 1 image hdus found.
# HDU 0 contains image data with shape (2238, 2249)
# 1 non empty images found.
# keyword is None
# No 'SCI' extname found.
# Using first hdu.
# Could not determine wavelength for F200W (/Users/tom/Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/Lenstool_GUI/examples/DATA/FILTERS/F200W_cropped.fits).
# 1 filters loaded from directory: FILTERS

# %%
model_path = DATA_dir + "/lens_model/arc_optimization/"
im.import_lenstool(model_path, use_wrapper=True)
im.lt.set_lt_z(6.2)
# Out:
# Columns found in catalog:
# {'ra': ['ra'], 'dec': ['dec'], 'a': ['a'], 'b': ['b'], 'theta': ['theta']}
# Column names to be used:
# {'ra': 'ra', 'dec': 'dec', 'a': 'a', 'b': 'b', 'theta': 'theta'}
# Lens redshift fixed at z=0.356
#
# A valid lenstool file was found: best.par
# --------------------
# Moving to /Users/tom/Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/Lenstool_GUI/examples/DATA/lens_model/arc_optimization/
# --------------------
# Loading best.par
# You are running openMP version of lenstool with 16 threads
# You can change number of threads by set environment variable OMP_NUM_THREADS
# dpl_maps.pkl found
# lt_curves.pkl found
# lt_magnification_maps.pkl found
# lt_caustics.pkl found
# 100%|████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 60.08it/s]
# Computing sources
# Columns found in catalog:
# {'ra': ['ra'], 'dec': ['dec'], 'a': ['a'], 'b': ['b'], 'theta': ['theta']}
# Column names to be used:
# {'ra': 'ra', 'dec': 'dec', 'a': 'a', 'b': 'b', 'theta': 'theta'}
# done
# Computing images
# Columns found in catalog:
# {'ra': ['ra'], 'dec': ['dec'], 'a': ['a'], 'b': ['b'], 'theta': ['theta']}
# Column names to be used:
# {'ra': 'ra', 'dec': 'dec', 'a': 'a', 'b': 'b', 'theta': 'theta'}
# Columns found in catalog:
# {'ra': ['ra'], 'dec': ['dec'], 'a': ['a'], 'b': ['b'], 'theta': ['theta']}
# Column names to be used:
# {'ra': 'ra', 'dec': 'dec', 'a': 'a', 'b': 'b', 'theta': 'theta'}
# done
# /Users/tom/Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/Lenstool_GUI/examples/DATA/lens_model/arc_optimization/best.par
# /Users/tom/Library/Mobile Documents/com~apple~CloudDocs/RESEARCH/PROCESS/Lenstool_GUI/examples/DATA/lens_model/arc_optimization
# 100%|████████████████████████████████████████████████████████████████████████| 349/349 [00:00<00:00, 427765.08it/s]

# %%
im.lt.plot()
# Out:
# Clearing galaxies...
# Clearing column labels...
# Clearing galaxies...
# Clearing column labels...
# QGraphicsScene::removeItem: item 0x600002c50100's scene (0x0) is different from this scene (0x600001a21440)

# %%
im.lt.start_simulate_image(filter='F200W')
# Out:
# Computing displacement maps (can take a little while)...
# done
# Computing critical curve (can take a little while)...
# COMP1: critic and caustic lines for source plane at z=6.200
# limitHigh(in arcsec)=1.000 limitLow(in arcsec)=0.050
# xmin=30.9 ymin=-42.4 xmax=35.6 ymax=-37.7
# done
# done
# 100%|████████████████████████████████████████████████████████████████████████| 367/367 [00:00<00:00, 496551.47it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 367/367 [00:00<00:00, 510381.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 367/367 [00:00<00:00, 499289.51it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 367/367 [00:00<00:00, 526439.66it/s]
# Select filter: [[F200W]]
# Using filter F200W
# Calculating RMS...
#
# Careful: EXPTIME not found in header. Using arbitrary value EXPTIME=1ks.
